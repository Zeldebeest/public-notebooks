# %%
from __future__ import division
# %load_ext autoreload
# %autoreload 2
no_target = ["/Users/zeldin/Dropbox/Stanford_Postdoc/CODING/cctbx_testing/100_L614_myo/"]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import os
import numpy as np
import matplotlib.pyplot as plt
import logging
import brewer2mpl
# Set up logging
reload(logging)  # work-around for IPython
FORMAT = '%(message)s'
logging.basicConfig(level=logging.INFO, format=FORMAT)
# pretty colors
cols = brewer2mpl.get_map('BrBG', 'Diverging', 3).mpl_colors
from xfel.clustering.cluster import Cluster
from xfel.clustering.cluster import SingleFrame
from xfel.clustering.cluster_groups import unit_cell_info
import pandas as pd

# %%
clu = Cluster.from_directories(no_target)

# %%
test_single = clu_all.members[0]

# %%
mil = test_single.miller_array
comp = mil.complete_set()

# %%
print list(mil)[:4]
print list(comp.indices())[:4]
# Out:
# ...
# [(0, 0, 1), (0, 0, -1), (0, 0, 2), (0, 0, -2)]

# %%
def mill_dict(mil):
    dic = {}
    for i in list(mil):
        dic[i[0]] = i[1:]
    return dic

# %%
d0 = mill_dict(mil)

# %%
all_millers = {m: None for m in list(comp.indices())} 
all_millers.copy
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
all_millers = {m: None for m in list(comp.indices())} 
I_dic = {all_millers.deep}
sigI_dic = {}

for m in clu.members[:10]:
    d0 = mill_dict(m.miller_array)
    lab = m.name
    I_dic['m'] = {}
    sigI_dic['m'] = {}
    for index in list(comp.indices()):
        if index in d0:
            I_dic[index] = {"I": d0[index][0], "SigI": d0[index][1]}
        else:
            img_dic[index] = None

# %%
df = pd.DataFrame(img_dic, dtype=float).T

# %%
print df.values.nbytes + df.index.nbytes + df.columns.nbytes
# Out:
# 3272592

# %%
df
# Out:
#             I  SigI
# -59 -2 -3 NaN   NaN
#        -2 NaN   NaN
#        -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
#         2 NaN   NaN
#         3 NaN   NaN
#     -1 -5 NaN   NaN
#        -4 NaN   NaN
#        -3 NaN   NaN
#        -2 NaN   NaN
#        -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
#         2 NaN   NaN
#         3 NaN   NaN
#         4 NaN   NaN
#         5 NaN   NaN
# -58 -4 -2 NaN   NaN
#        -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
#         2 NaN   NaN
#     -3 -5 NaN   NaN
#        -4 NaN   NaN
#        -3 NaN   NaN
#        -2 NaN   NaN
#        -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
# ...        ..   ...
#  58  3 -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
#         2 NaN   NaN
#         3 NaN   NaN
#         4 NaN   NaN
#         5 NaN   NaN
#      4 -2 NaN   NaN
#        -1 NaN   NaN
#         0 NaN   NaN
#         1 NaN   NaN
#         2 NaN   NaN
#  59  1 -5 NaN   NaN
# ...

# %%
test.values.nbytes + test.index.nbytes + test.columns.nbytes
# Out:
# 7920
